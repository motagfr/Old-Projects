# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.17.0

# %% [markdown]
# ## Load a dataset

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# Here we will flatten the images so that they can be used as input. Dropout deals with the problem of overfitting by ignoring some nodes in every iteration.

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])
# Out:
# c:\Users\M\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Here we use SparseCategoricalCrossentropy because we have not one-hot-encoded the output and we use from_logits=True because we donhave have not used Softmax. Softmax needs a lot of memory to store digits that's why it's often ignored and instead from_logits is used.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# Here the number of epochs is low because there is a lot of data and therefore a lot of iterations in each epoch, so the network can learn in fewer epochs. What's most important in the process of learning is the number of iterations.

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8620 - loss: 0.4745
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9547 - loss: 0.1555
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9664 - loss: 0.1118
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9725 - loss: 0.0888
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9766 - loss: 0.0773

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 0s - 1ms/step - accuracy: 0.9760 - loss: 0.0772
# [0.07724419236183167, 0.9760000109672546]

# %%
y_test[12]
# Out:
# 9

# %%
x_test[10].shape
# Out:
# (28, 28)

# %% [markdown]
# Here we reshape the x_test[12] because we must give is as a SAMPLE to the model.

# %%
test_sample = x_test[12].reshape(1,28,28)

# %%
model.predict(test_sample)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# array([[-10.771002  , -12.090485  ,  -7.9728613 ,  -1.2561799 ,
#           1.130453  ,  -3.4247303 , -11.026224  ,   0.29060346,
#          -4.7869115 ,   9.452145  ]], dtype=float32)

# %%
probability_model = tf.keras.Sequential([
  model,
  tf.keras.layers.Softmax()
])

# %%
probability_model.predict(test_sample)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# array([[1.6483021e-09, 4.4054749e-10, 2.7055366e-08, 2.2349692e-05,
#         2.4309332e-04, 2.5555362e-06, 1.2770127e-09, 1.0496173e-04,
#         6.5447711e-07, 9.9962640e-01]], dtype=float32)
