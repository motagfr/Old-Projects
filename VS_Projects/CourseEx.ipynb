# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
moviesDF=pd.read_csv('c:\\IMDB-Movie-Data.csv')
moviesDF.head()
# Out:
#    Rank                    Title                     Genre
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     3                    Split           Horror,Thriller
# 4     4                     Sing   Animation,Comedy,Family
#
#                                          Description              Director
# 0  A group of intergalactic criminals are forced ...            James Gunn  \
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
#
#                                               Actors  Year  Runtime (Minutes)
# ...

# %%
moviesDF.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
moviesDF.shape
# Out:
# (1024, 12)

# %%
moviesDF.info
# Out:
# <bound method DataFrame.info of       Rank                    Title                     Genre
# 0        1  Guardians of the Galaxy   Action,Adventure,Sci-Fi  \
# 1        2               Prometheus  Adventure,Mystery,Sci-Fi
# 2        3                    Split           Horror,Thriller
# 3        3                    Split           Horror,Thriller
# 4        4                     Sing   Animation,Comedy,Family
# ...    ...                      ...                       ...
# 1019   996     Secret in Their Eyes       Crime,Drama,Mystery
# 1020   997          Hostel: Part II                    Horror
# 1021   998   Step Up 2: The Streets       Drama,Music,Romance
# 1022   999             Search Party          Adventure,Comedy
# 1023  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                             Description              Director
# 0     A group of intergalactic criminals are forced ...            James Gunn  \
# ...

# %%
moviesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024 entries, 0 to 1023
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1024 non-null   int64
#  1   Title               1024 non-null   object
#  2   Genre               1024 non-null   object
#  3   Description         1024 non-null   object
#  4   Director            1024 non-null   object
#  5   Actors              1024 non-null   object
#  6   Year                1024 non-null   int64
#  7   Runtime (Minutes)   1024 non-null   int64
#  8   Rating              1024 non-null   float64
#  9   Votes               1024 non-null   int64
#  10  Revenue (Millions)  896 non-null    float64
#  11  Metascore           960 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 96.1+ KB

# %%
moviesDF.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes
# count  1024.000000  1024.000000        1024.000000  1024.000000  1.024000e+03  \
# mean    490.249023  2012.812500         113.746094     6.741113  1.769684e+05
# std     293.020108     3.202516          19.272648     0.950495  2.018283e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     232.750000  2010.000000         100.000000     6.200000  3.831625e+04
# 50%     488.500000  2014.000000         111.000000     6.800000  1.130870e+05
# 75%     744.250000  2016.000000         124.000000     7.400000  2.470792e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          896.000000  960.000000
# mean            86.818806   59.141667
# std            110.067305   17.100657
# min              0.000000   11.000000
# 25%             13.650000   47.000000
# ...

# %%
moviesDF.describe(include='all')
# Out:
#                Rank         Title                    Genre
# count   1024.000000          1024                     1024  \
# unique          NaN           999                      207
# top             NaN  Ghostbusters  Action,Adventure,Sci-Fi
# freq            NaN             2                       54
# mean     490.249023           NaN                      NaN
# std      293.020108           NaN                      NaN
# min        1.000000           NaN                      NaN
# 25%      232.750000           NaN                      NaN
# 50%      488.500000           NaN                      NaN
# 75%      744.250000           NaN                      NaN
# max     1000.000000           NaN                      NaN
#
#                                               Description      Director
# count                                                1024          1024  \
# unique                                               1000           644
# ...

# %%
moviesDF[['Title','Rank']]
# Out:
#                         Title  Rank
# 0     Guardians of the Galaxy     1
# 1                  Prometheus     2
# 2                       Split     3
# 3                       Split     3
# 4                        Sing     4
# ...                       ...   ...
# 1019     Secret in Their Eyes   996
# 1020          Hostel: Part II   997
# 1021   Step Up 2: The Streets   998
# 1022             Search Party   999
# 1023               Nine Lives  1000
#
# [1024 rows x 2 columns]

# %%
moviesDF.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1019    False
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# Length: 1024, dtype: bool

# %%
moviesDF[moviesDF.duplicated()]
# Out:
#      Rank                                       Title
# 3       3                                       Split  \
# 15     14                                       Moana
# 39     31                                    Why Him?
# 40     32                           Nocturnal Animals
# 41     33                           X-Men: Apocalypse
# 42     34                                    Deadpool
# 43     35            Resident Evil: The Final Chapter
# 44     36                  Captain America: Civil War
# 45     37                                Interstellar
# 100    77                                The Avengers
# 101    78                        Inglourious Basterds
# 102    79  Pirates of the Caribbean: Dead Man's Chest
# 103    80                                Ghostbusters
# 104    81                                   Inception
# 105    82                           Captain Fantastic
# 106    83                     The Wolf of Wall Street
# ...

# %%
moviesDF.drop_duplicates(inplace=True)
moviesDF.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 4       False
# 5       False
#         ...
# 1019    False
# 1020    False
# 1021    False
# 1022    False
# 1023    False
# Length: 1000, dtype: bool

# %%
moviesDF.reset_index(drop=True,inplace=True)
moviesDF.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
moviesDF.isnull()
# Out:
#        Rank  Title  Genre  Description  Director  Actors   Year
# 0     False  False  False        False     False   False  False  \
# 1     False  False  False        False     False   False  False
# 2     False  False  False        False     False   False  False
# 4     False  False  False        False     False   False  False
# 5     False  False  False        False     False   False  False
# ...     ...    ...    ...          ...       ...     ...    ...
# 1019  False  False  False        False     False   False  False
# 1020  False  False  False        False     False   False  False
# 1021  False  False  False        False     False   False  False
# 1022  False  False  False        False     False   False  False
# 1023  False  False  False        False     False   False  False
#
#       Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                 False   False  False               False      False
# ...

# %%
moviesDF.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
moviesDF.fillna(moviesDF['Revenue (Millions)'].sum(),inplace=True)
moviesDF.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
moviesDF.set_index('Title',inplace=True)

# %%
moviesDF
# Out:
#                          Rank                     Genre
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi  \
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...  \
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
l=list()
type(l)
# Out:
# list

# %%
moviesDF['Actors']
# Out:
# Title
# Guardians of the Galaxy    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus                 Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                       Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad              Will Smith, Jared Leto, Margot Robbie, Viola D...
#                                                  ...
# Secret in Their Eyes       Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II            Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets     Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party               Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives                 Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Name: Actors, Length: 1000, dtype: object

# %%
moviesDF['Actors'][0]
# Out:
# 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana'

# %%
type(moviesDF['Actors'][0])
# Out:
# str

# %%
moviesDF['Lead Actor']=moviesDF['Actors'].apply(lambda x:x.split(',')[0])

# %%
moviesDF.head()
# Out:
#                          Rank                     Genre
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi  \
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...  \
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director
# Title
# Guardians of the Galaxy            James Gunn  \
# Prometheus                       Ridley Scott
# ...
